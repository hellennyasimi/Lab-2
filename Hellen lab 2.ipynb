# %% [markdown]
# ## let's import and read the data

# %%
pip install matplotlib --upgrade
# Out:
# Requirement already satisfied: matplotlib in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (3.6.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.24.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nicky\appdata\roaming\python\python311\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nicky\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nicky\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nicky\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
DATA_URL="datasets/"

# %%
data = pd.read_csv(DATA_URL + "adult_train.csv")
data.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# ## more details about  the data

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.columns
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education_Num',
#        'Martial_Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_Gain', 'Capital_Loss', 'Hours_per_week', 'Country', 'Target'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age                int64
# Workclass         object
# fnlwgt             int64
# Education         object
# Education_Num      int64
# Martial_Status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_Gain       int64
# Capital_Loss       int64
# Hours_per_week     int64
# Country           object
# Target            object
# dtype: object

# %%
data.describe()
# Out:
#                 Age        fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of        Age          Workclass  fnlwgt    Education  Education_Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Martial_Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_Gain  Capital_Loss  Hours_per_week         Country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        Target
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]>

# %% [markdown]
# ## let's study the data

# %%
data.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df = data[['Age','fnlwgt','Education_Num','Capital_Gain','Capital_Loss',
         #'Workclass', 'Education', 
    #'Martial_Status', 
    #'Occupation', 
    #'Relationship', 'Race', 'Sex','Country','Target',
    'Hours_per_week']].copy()

# %%
df.shape
# Out:
# (32561, 6)

# %%
df.dtypes
# Out:
# Age               int64
# fnlwgt            int64
# Education_Num     int64
# Capital_Gain      int64
# Capital_Loss      int64
# Hours_per_week    int64
# dtype: object

# %%
df = df.rename(columns={'fnlwgt':'Final_Weight'})

# %%
df.head()
# Out:
#    Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 0   39         77516             13          2174             0
# 1   50         83311             13             0             0
# 2   38        215646              9             0             0
# 3   53        234721              7             0             0
# 4   28        338409             13             0             0
#
#    Hours_per_week
# 0              40
# 1              13
# 2              40
# 3              40
# 4              40

# %% [markdown]
# #### find if there's missing data

# %%
df.isna().sum()
# Out:
# Age               0
# Final_Weight      0
# Education_Num     0
# Capital_Gain      0
# Capital_Loss      0
# Hours_per_week    0
# dtype: int64

# %% [markdown]
# ### check for any duplicated data

# %%
df.loc[df.duplicated()]
# Out:
#        Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 3261    26        108658              9             0             0
# 3692    46        271828              9             0             0
# 3781    23        200973              9             0             0
# 4881    25        308144             13             0             0
# 4942    17        139183              6             0             0
# ...    ...           ...            ...           ...           ...
# 32323   32        188246              9             0             0
# 32346   33        205950              9             0             0
# 32352   28        119793              9             0             0
# 32404   35        379959              9             0             0
# 32555   22        310152             10             0             0
#
#        Hours_per_week
# 3261               40
# 3692               40
# 3781               40
# 4881               40
# 4942               15
# ...               ...
# 32323              40
# 32346              40
# 32352              40
# 32404              40
# 32555              40
#
# [227 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
df.loc[df.duplicated(subset=['Final_Weight'])].head(5)
# Out:
#      Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 443   44        116632             10             0             0
# 460   44        116632             12             0             0
# 594   23        117789             13             0             0
# 680   29         92262              9             0             0
# 719   34        217460             13             0             0
#
#      Hours_per_week
# 443              40
# 460              40
# 594              40
# 680              48
# 719              45

# %%
df.columns
# Out:
# Index(['Age', 'Final_Weight', 'Education_Num', 'Capital_Gain', 'Capital_Loss',
#        'Hours_per_week'],
#       dtype='object')

# %%
df=df.loc[~df.duplicated(subset=['Final_Weight','Education_Num','Age'])]\
.reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (31598, 6)

# %% [markdown]
# ##Step 3: Feature Understanding

# %% [markdown]
# (Univariate analysis)

# %%
df['Hours_per_week']. value_counts()
# Out:
# 40    14800
# 50     2725
# 45     1766
# 60     1426
# 35     1252
#       ...
# 82        1
# 94        1
# 92        1
# 87        1
# 74        1
# Name: Hours_per_week, Length: 94, dtype: int64

# %%
ax=df['Hours_per_week']. value_counts()\
.head(10)\
.plot(kind='bar',title='Working Hours Per Week')
ax.set_xlabel('Working Hours')
ax.set_ylabel('Amount of Peoples')
# Out:
# Text(0, 0.5, 'Amount of Peoples')

# %%
ax=df['Final_Weight'].plot(kind='hist',
                           bins=40, 
                           title="Final Weight")
ax.set_xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
ax=df['Final_Weight'].plot(kind='kde',
                           title="Final Weight")
ax.set_xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %% [markdown]
# ## correlations

# %% [markdown]
# ### here we're going to use scatterplot and pairplot to feature the correlation.

# %%
df.plot(kind='scatter',
        x='Hours_per_week',
        y='Final_Weight',
       title='Hours per week vs. Final Weight')
plt.show()

# %%
sns.scatterplot(x='Age',
                y='Final_Weight',
                hue="Education_Num",
                data=df)
plt.show()

# %%
df
# Out:
#        Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 0       39         77516             13          2174             0
# 1       50         83311             13             0             0
# 2       38        215646              9             0             0
# 3       53        234721              7             0             0
# 4       28        338409             13             0             0
# ...    ...           ...            ...           ...           ...
# 31593   27        257302             12             0             0
# 31594   40        154374              9             0             0
# 31595   58        151910              9             0             0
# 31596   22        201490              9             0             0
# 31597   52        287927              9         15024             0
#
#        Hours_per_week
# 0                  40
# 1                  13
# 2                  40
# 3                  40
# 4                  40
# ...               ...
# 31593              38
# 31594              40
# 31595              40
# 31596              20
# 31597              40
#
# [31598 rows x 6 columns]

# %%
df.dtypes
# Out:
# Age               int64
# Final_Weight      int64
# Education_Num     int64
# Capital_Gain      int64
# Capital_Loss      int64
# Hours_per_week    int64
# dtype: object

# %%
sns.pairplot(df,vars=['Age','Final_Weight','Education_Num','Hours_per_week','Capital_Gain','Capital_Loss'])
plt.show()

# %%
df_corr=df[['Age','Final_Weight','Education_Num','Hours_per_week','Capital_Gain','Capital_Loss']].dropna().corr()
df_corr
# Out:
#                      Age  Final_Weight  Education_Num  Hours_per_week  \
# Age             1.000000     -0.079047       0.037006        0.063986
# Final_Weight   -0.079047      1.000000      -0.043175       -0.018327
# Education_Num   0.037006     -0.043175       1.000000        0.149690
# Hours_per_week  0.063986     -0.018327       0.149690        1.000000
# Capital_Gain    0.077314      0.000052       0.122563        0.076902
# Capital_Loss    0.057897     -0.011251       0.078928        0.052837
#
#                 Capital_Gain  Capital_Loss
# Age                 0.077314      0.057897
# Final_Weight        0.000052     -0.011251
# Education_Num       0.122563      0.078928
# Hours_per_week      0.076902      0.052837
# Capital_Gain        1.000000     -0.031754
# Capital_Loss       -0.031754      1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Findig the class with the longest working hours for a week?

# %%
df.head()
# Out:
#    Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 0   39         77516             13          2174             0
# 1   50         83311             13             0             0
# 2   38        215646              9             0             0
# 3   53        234721              7             0             0
# 4   28        338409             13             0             0
#
#    Hours_per_week
# 0              40
# 1              13
# 2              40
# 3              40
# 4              40

# %%
ax=data.query('Workclass != "Self-emp-not-inc"')\
.groupby('Workclass')['Hours_per_week']\
.agg(['mean','count'])\
.query('count >= 100')\
.sort_values('mean') ['mean']\
.plot(kind='barh', figsize=(12,5), title='Average Working Hours Per Week by Workclass')
ax.set_xlabel('Average Working Hours Per Week')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### For my conclusion,based on the given graph, I can conclude that Self-emp-incs have the longest average working hours in a week.

# %%
print(df)
# Out:
#        Age  Final_Weight  Education_Num  Capital_Gain  Capital_Loss  \
# 0       39         77516             13          2174             0
# 1       50         83311             13             0             0
# 2       38        215646              9             0             0
# 3       53        234721              7             0             0
# 4       28        338409             13             0             0
# ...    ...           ...            ...           ...           ...
# 31593   27        257302             12             0             0
# 31594   40        154374              9             0             0
# 31595   58        151910              9             0             0
# 31596   22        201490              9             0             0
# 31597   52        287927              9         15024             0
#
#        Hours_per_week
# 0                  40
# 1                  13
# 2                  40
# 3                  40
# 4                  40
# ...               ...
# 31593              38
# 31594              40
# 31595              40
# 31596              20
# 31597              40
#
# [31598 rows x 6 columns]

# %%
# %matplotlib inline

# %%
df1 = df.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
# Загрузка данных из файла
from sklearn.impute import SimpleImputer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
empty_cols = [column for column in df1.columns if column not in ['Age', 'Hours_per_week']]
non_id_cols = [column for column in df1.columns if column != 'Age']

imputer = SimpleImputer(missing_values=0, strategy='median')
empty_transformer = ColumnTransformer(
    [('impute', imputer, empty_cols)],
    remainder='passthrough',    #Did not touch the other columns
    verbose_feature_names_out=False)    #Did not add a prefix to the column names  
empty_transformer.set_output(transform='pandas')  #Output to a table, not an array

scaler = StandardScaler()
scale_transformer = ColumnTransformer(
    [('scale', scaler, non_id_cols)],
    remainder='passthrough',    #Did not touch the other columns
    verbose_feature_names_out=False)    #Did not add a prefix to the column names 
scale_transformer.set_output(transform='pandas')  #Output to a table, not an array

preproc_pipeline = Pipeline([
    ('imputer', empty_transformer),
    ('scaler', scale_transformer)]
)
preproc_pipeline
# Out:
# Pipeline(steps=[('imputer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute',
#                                                   SimpleImputer(missing_values=0,
#                                                                 strategy='median'),
#                                                   ['Final_Weight',
#                                                    'Education_Num',
#                                                    'Capital_Gain',
#                                                    'Capital_Loss'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scale', StandardScaler(),
#                                                   ['Final_Weight',
#                                                    'Education_Num',
#                                                    'Capital_Gain',
#                                                    'Capital_Loss',
#                                                    'Hours_per_week'])],
#                                    verbose_feature_names_out=False))])

# %%
df1 = df.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
df1.hist(bins=50,figsize=(20,15))
plt.show();

# %%
from sklearn.model_selection import StratifiedShuffleSplit

data = df1[non_id_cols]
labels = df1['Education_Num']

shuffle = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=12345)

for idx_train, idx_test in shuffle.split(data, labels):
    pass

X_test = data.iloc[idx_test]
y_test = labels.iloc[idx_test]

X_train = data.iloc[idx_train]
y_train = labels.iloc[idx_train]

# %%
print(X_train)
# Out:
#        Final_Weight  Education_Num  Capital_Gain  Capital_Loss  Hours_per_week
# 22402        186452              9             0             0              50
# 22201        226267              4             0             0              43
# 548          259510              9             0             0              36
# 31193        109814             15             0          1977              45
# 5034         165309             10             0             0              43
# ...             ...            ...           ...           ...             ...
# 8541         102858             12             0          2002              42
# 4139         107112              4             0             0              30
# 19774        106982             10             0             0              40
# 26381        159869              9             0             0              56
# 23349        188303             10          7688             0              40
#
# [25278 rows x 5 columns]

# %%
print(y_train)
# Out:
# 22402     9
# 22201     4
# 548       9
# 31193    15
# 5034     10
#          ..
# 8541     12
# 4139      4
# 19774    10
# 26381     9
# 23349    10
# Name: Education_Num, Length: 25278, dtype: int64

# %%
df.dtypes
# Out:
# Age               int64
# Final_Weight      int64
# Education_Num     int64
# Capital_Gain      int64
# Capital_Loss      int64
# Hours_per_week    int64
# dtype: object

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, roc_auc_score
import pickle

classifiers = {
    'logistic_regression': (LogisticRegression(solver='saga', max_iter = 1000, random_state=123),
        {'clf__C': uniform(loc=0.1, scale=10), 'clf__penalty': ['l2', 'l1']}),
    'support_vectors': (SVC(kernel='poly'),
        {'clf__C': uniform(loc=0.1, scale=10), 'clf__degree': randint(2,5), 
        'clf__gamma': uniform(loc = 0, scale = 1), 'clf__coef0': uniform(loc=-1, scale=2)}),
    'knn': (KNeighborsClassifier(),
        {'clf__n_neighbors': randint(2,10), 'clf__p': randint(1,3)}),
    'bayes': (GaussianNB(),
        {'clf__var_smoothing': uniform(loc=1e-10, scale=1)}),
    'random_forest': (RandomForestClassifier(random_state=123),
        {'clf__n_estimators': randint(100,300), 'clf__max_features': ['sqrt', 'log2'], 
        'clf__min_samples_split': randint(2,5)}
    )
}

dataframe = pd.DataFrame(['accuracy', 'recall', 'precision', 'ROC AUC curve'])

for name, values in classifiers.items():
    clf, params = values
    pipeline = Pipeline([
        ("preproc", preproc_pipeline),
        ('clf', clf)]
    )
    model = RandomizedSearchCV(pipeline, params)

    model.fit(X_train, y_train)

    with open(f"saved_models/{name}.pkl", "wb") as file:
        pickle.dump(model, file, protocol=3)
    with open(f"hyperparams/{name}.txt", "w") as file:
        file.write(str(model.best_params_))
    print(name)
    print(model.best_params_, '\n' + '=' * 20)

    y_pred = model.predict(X_test)
    y_true = np.array(y_test)

    dataframe[name] = [accuracy_score(y_true, y_pred), recall_score(y_true, y_pred), 
    precision_score(y_true, y_pred), roc_auc_score(y_true, y_pred)]

    print(  f'Confusion matrix:\n {confusion_matrix(y_true, y_pred)}\n'
    )

dataframe
# Out:
# c:\Users\nicky\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
